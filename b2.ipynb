# %%
import numpy as np # linear algebra
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt

# %matplotlib inline
import seaborn as sns
#Seaborn has five different themes: (1)"darkgrid", (2)"whitegrid", (3)"dark", (4)"white", and (5)"ticks"

# %%
import cv2

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-dd507223-4eec-4d3a-8371-80585539daf5" name="files[]" multiple disabled />
#      <output id="result-dd507223-4eec-4d3a-8371-80585539daf5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image.png to image.png
# ...

# %%
img = cv2.imread('image.png', cv2.IMREAD_UNCHANGED)

# %%
  from google.colab.patches import cv2_imshow

  cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=640x544 at 0x7FCC7E9B4A90>

# %%
img.shape
# Out:
# (544, 640, 4)

# %%
# 2.1
w=int(img.shape[0]/2)
h=int(img.shape[1]/2)

top_left = img[0:w, 0:h]

cv2_imshow(new_img)
# Out:
# <PIL.Image.Image image mode=RGBA size=320x272 at 0x7FCC7C809E48>

# %%
# 2.2
half_img = cv2.resize(img, (w, h), interpolation = cv2.INTER_AREA)
cv2_imshow(half_img)
# Out:
# <PIL.Image.Image image mode=RGBA size=272x320 at 0x7FCC7C7CC278>

# %%
# 2.3
blurred_img = cv2.GaussianBlur(img, (5,5), cv2.BORDER_DEFAULT)
cv2_imshow(blurred_img)
# Out:
# <PIL.Image.Image image mode=RGBA size=640x544 at 0x7FCC7C7E1780>

# %%
# 2.4
edges_img = cv2.Canny(img, 100, 200)
cv2_imshow(edges_img)
# Out:
# <PIL.Image.Image image mode=L size=640x544 at 0x7FCC7C7E1A20>

# %%
import numpy as np # linear algebra
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt

# %matplotlib inline
import seaborn as sns

df = pd.read_csv('./datasets/dataset_entry_test/data_linear.csv')

# Set the width and height of the figure
plt.figure(figsize=(20,6))

# Add title
plt.title("Relationship of Area and Price")

sns.scatterplot(x=df['Diện tích'], y=df['Giá'])
sns.regplot(x=df['Diện tích'], y=df['Giá'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-4b686e571050> in <module>()
#       7 import seaborn as sns
#       8
# ----> 9 df = pd.read_csv('./datasets/dataset_entry_test/data_linear.csv')
#      10
#      11 # Set the width and height of the figure
#
# ...
