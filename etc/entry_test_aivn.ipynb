# %%
# import jtplot submodule from jupyterthemes
from jupyterthemes import jtplot

# currently installed theme will be used to
# set plot style if no arguments provided
# jtplot.style(theme='oceans16')
jtplot.style('chesterish')

# %%
import numpy as np # linear algebra
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt

# %matplotlib inline
import seaborn as sns
#Seaborn has five different themes: (1)"darkgrid", (2)"whitegrid", (3)"dark", (4)"white", and (5)"ticks"

# %%
df = pd.read_csv('./datasets/dataset_entry_test/data_linear.csv')

# %%
df.describe()
# Out:
#         Diện tích          Giá
# count   30.000000    30.000000
# mean    65.000000   981.656633
# std     21.249598   323.623977
# min     30.000000   448.524000
# 25%     47.500025   713.262250
# 50%     65.000000   973.896000
# 75%     82.499975  1248.992500
# max    100.000000  1515.280000

# %%
# Set the width and height of the figure
plt.figure(figsize=(50,6))

# Add title
plt.title("Relationship of Area and Price")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=df['Diện tích'], y=df['Giá'])

# %%
# Set the width and height of the figure
plt.figure(figsize=(20,6))

# Add title
plt.title("Relationship of Area and Price")

sns.scatterplot(x=df['Diện tích'], y=df['Giá'])
sns.regplot(x=df['Diện tích'], y=df['Giá'])

# %%
import numpy as np # linear algebra
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt

# %matplotlib inline
import seaborn as sns

df = pd.read_csv('./datasets/dataset_entry_test/data_linear.csv')

# Set the width and height of the figure
plt.figure(figsize=(20,6))

# Add title
plt.title("Relationship of Area and Price")

sns.scatterplot(x=df['Diện tích'], y=df['Giá'])
sns.regplot(x=df['Diện tích'], y=df['Giá'])

# %%
a = np.array([[1, 2, 3], [5, 1, 1], [3, 2, 1], [1, 1, 1]])
b = np.array([[4, 2, 1], [5, 5, 1], [1, 2, 1], [1, 2, 4]])

# %%
a+b
# Out:
# array([[ 5,  4,  4],
#        [10,  6,  2],
#        [ 4,  4,  2],
#        [ 2,  3,  5]])

# %%
a-b
# Out:
# array([[-3,  0,  2],
#        [ 0, -4,  0],
#        [ 2,  0,  0],
#        [ 0, -1, -3]])

# %%
np.matmul(a.transpose(), b)
# Out:
# array([[33, 35, 13],
#        [16, 15,  9],
#        [19, 15,  9]])

# %%
A = np.array([[1, -1, -1], [1, 3, 1], [-3, 1, -1]])
np.linalg.eig(A)
# Out:
# (array([-2.,  2.,  3.]),
#  array([[ 2.35702260e-01, -7.07106781e-01, -5.77350269e-01],
#         [-2.35702260e-01,  7.45148041e-16,  5.77350269e-01],
#         [ 9.42809042e-01,  7.07106781e-01,  5.77350269e-01]]))

# %%
np.linalg.eigvals(A)
# Out:
# array([-2.,  2.,  3.])
